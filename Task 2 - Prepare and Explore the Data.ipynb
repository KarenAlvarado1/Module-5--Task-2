# %%
# Part 1 - Import and Prepare Data

# %%
import pandas as pd

# %%
credit = pd.read_csv('default of credit card clients.csv', header =1)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...                      0          0          0         0
# 1             ...                   3272       3455       3261         0
# 2             ...                  14331      14948      15549      1518
# 3             ...                  28314      28959      29547      2000
# 4             ...                  20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
# Pre-processing the data

# %%
len(credit)
# Out:
# 30000

# %%
credit.groupby(by='AGE')

# %%
credit.plot.hist('AGE')

# %%
credit.expanding()
# Out:
# Expanding [min_periods=1,center=False,axis=0]

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
credit.AGE.value_counts().plot(kind='bar')

# %%
credit.SEX.value_counts().plot(kind='bar')

# %%
credit.shape
# Out:
# (30000, 25)

# %%
credit.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
pd.value_counts('LIMIT_BAL')
# Out:
# LIMIT_BAL    9
# dtype: int64

# %%
credit.ix[0,0:6]
# Out:
# C:\Users\kalvarado\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# ID               1
# LIMIT_BAL    20000
# SEX              2
# EDUCATION        2
# MARRIAGE         1
# AGE             24
# Name: 0, dtype: int64

# %%
credit['AGE'].value_counts()
# Out:
# 29    1605
# 27    1477
# 28    1409
# 30    1395
# 26    1256
# 31    1217
# 25    1186
# 34    1162
# 32    1158
# 33    1146
# 24    1127
# 35    1113
# 36    1108
# 37    1041
# 39     954
# 38     944
# 23     931
# 40     870
# 41     824
# 42     794
# 44     700
# 43     670
# 45     617
# 46     570
# 22     560
# 47     501
# 48     466
# 49     452
# 50     411
# 51     340
# 53     325
# 52     304
# 54     247
# 55     209
# 56     178
# 58     122
# 57     122
# 59      83
# 60      67
# 21      67
# 61      56
# 62      44
# 63      31
# 64      31
# 66      25
# 65      24
# 67      16
# 69      15
# 70      10
# 68       5
# 73       4
# 71       3
# 72       3
# 75       3
# 74       1
# 79       1
# Name: AGE, dtype: int64

# %%
credit['SEX'].value_counts()
# Out:
# 2    18112
# 1    11888
# Name: SEX, dtype: int64

# %%
credit['EDUCATION'].value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 5      280
# 4      123
# 6       51
# 0       14
# Name: EDUCATION, dtype: int64

# %%
credit['MARRIAGE'].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64

# %%
credit.dtypes
# Out:
# ID                            int64
# LIMIT_BAL                     int64
# SEX                           int64
# EDUCATION                     int64
# MARRIAGE                      int64
# AGE                           int64
# PAY_0                         int64
# PAY_2                         int64
# PAY_3                         int64
# PAY_4                         int64
# PAY_5                         int64
# PAY_6                         int64
# BILL_AMT1                     int64
# BILL_AMT2                     int64
# BILL_AMT3                     int64
# BILL_AMT4                     int64
# BILL_AMT5                     int64
# BILL_AMT6                     int64
# PAY_AMT1                      int64
# PAY_AMT2                      int64
# PAY_AMT3                      int64
# PAY_AMT4                      int64
# PAY_AMT5                      int64
# PAY_AMT6                      int64
# default payment next month    int64
# dtype: object

# %%
credit['PAY_0'].value_counts()
# Out:
#  0    14737
# -1     5686
#  1     3688
# -2     2759
#  2     2667
#  3      322
#  4       76
#  5       26
#  8       19
#  6       11
#  7        9
# Name: PAY_0, dtype: int64

# %%
credit['PAY_2'].value_counts()
# Out:
#  0    15730
# -1     6050
#  2     3927
# -2     3782
#  3      326
#  4       99
#  1       28
#  5       25
#  7       20
#  6       12
#  8        1
# Name: PAY_2, dtype: int64

# %%
credit['PAY_3'].value_counts()
# Out:
#  0    15764
# -1     5938
# -2     4085
#  2     3819
#  3      240
#  4       76
#  7       27
#  6       23
#  5       21
#  1        4
#  8        3
# Name: PAY_3, dtype: int64

# %%
credit['PAY_4'].value_counts()
# Out:
#  0    16455
# -1     5687
# -2     4348
#  2     3159
#  3      180
#  4       69
#  7       58
#  5       35
#  6        5
#  8        2
#  1        2
# Name: PAY_4, dtype: int64

# %%
credit['PAY_5'].value_counts()
# Out:
#  0    16947
# -1     5539
# -2     4546
#  2     2626
#  3      178
#  4       84
#  7       58
#  5       17
#  6        4
#  8        1
# Name: PAY_5, dtype: int64

# %%
credit['PAY_6'].value_counts()
# Out:
#  0    16286
# -1     5740
# -2     4895
#  2     2766
#  3      184
#  4       49
#  7       46
#  6       19
#  5       13
#  8        2
# Name: PAY_6, dtype: int64

# %%
credit['BILL_AMT1'].value_counts()
# Out:
#  0         2008
#  390        244
#  780         76
#  326         72
#  316         63
#  2500        59
#  396         49
#  2400        39
#  416         29
#  500         25
#  1050        25
#  1473        24
# -200         22
#  1261        22
# -5           22
#  836         21
#  264         20
# -3           19
#  291         19
#  600         18
# -2           17
#  360         17
# -4           16
#  1000        16
# -1           16
#  150         14
#  300         14
#  200         14
#  325         14
#  632         13
#            ...
#  33370        1
#  35419        1
#  78428        1
#  47709        1
#  10847        1
#  16994        1
#  19043        1
#  225892       1
#  31333        1
#  29252        1
#  68859        1
#  285249       1
#  16946        1
#  39465        1
#  33322        1
#  2603         1
#  47661        1
#  74286        1
# -33           1
#  250416       1
#  225844       1
#  48596        1
#  31285        1
#  93625        1
# ...

# %%
credit['PAY_AMT1'].value_counts()
# Out:
# 0         5249
# 2000      1363
# 3000       891
# 5000       698
# 1500       507
# 4000       426
# 10000      401
# 1000       365
# 2500       298
# 6000       294
# 390        207
# 7000       195
# 3500       185
# 1300       184
# 8000       176
# 1600       174
# 1800       167
# 1700       157
# 1200       136
# 2100       129
# 4500       108
# 2200       108
# 1400        97
# 15000       97
# 3200        84
# 20000       80
# 9000        80
# 2300        70
# 6500        70
# 11000       68
#           ...
# 236          1
# 13952        1
# 40453        1
# 16001        1
# 10473        1
# 71316        1
# 20710        1
# 24800        1
# 7845         1
# 34470        1
# 3671         1
# 1622         1
# 5716         1
# 20047        1
# 10505        1
# 50702        1
# 19983        1
# 160002       1
# 6972         1
# 3607         1
# 4350         1
# 5668         1
# 252          1
# 20015        1
# 7733         1
# 24125        1
# 20031        1
# ...

# %%
credit['default payment next month'].value_counts()
# Out:
# 0    23364
# 1     6636
# Name: default payment next month, dtype: int64

# %%
# Part 2 - Perform Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
plt.hist(credit['LIMIT_BAL'])
plt.show()

# %%
plt.hist(credit['LIMIT_BAL'], bins=4)
# Out:
# (array([  2.32830000e+04,   6.51100000e+03,   2.00000000e+02,
#           6.00000000e+00]),
#  array([   10000.,   257500.,   505000.,   752500.,  1000000.]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(credit['LIMIT_BAL'], bins=7)
# Out:
# (array([  1.64000000e+04,   8.48300000e+03,   3.64200000e+03,
#           1.36300000e+03,   9.50000000e+01,   1.60000000e+01,
#           1.00000000e+00]),
#  array([   10000.        ,   151428.57142857,   292857.14285714,
#           434285.71428571,   575714.28571429,   717142.85714286,
#           858571.42857143,  1000000.        ]),
#  <a list of 7 Patch objects>)

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
sns.factorplot("EDUCATION", "SEX", data=credit, palette="BuPu_d")
# Out:
# C:\Users\kalvarado\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
plt.hist(credit['LIMIT_BAL'], bins=5)
# Out:
# (array([  2.03780000e+04,   7.81800000e+03,   1.72500000e+03,
#           7.80000000e+01,   1.00000000e+00]),
#  array([   10000.,   208000.,   406000.,   604000.,   802000.,  1000000.]),
#  <a list of 5 Patch objects>)

# %%
plt.hist(credit['SEX'], bins=2)
# Out:
# (array([ 11888.,  18112.]),
#  array([ 1. ,  1.5,  2. ]),
#  <a list of 2 Patch objects>)

# %%
credit.SEX.value_counts().plot(kind='bar')

# %%
credit.MARRIAGE.value_counts().plot(kind='bar')

# %%
credit.EDUCATION.value_counts().plot(kind='bar')

# %%
#Line plots

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %%
x = credit['PAY_0']
y = credit['PAY_2']

# %%
plt.scatter(x,y)
plt.show()

# %%
#Box plots

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
A = credit['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
#Correlation

# %%
corrMat = credit.corr()
print(corrMat)
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
#Covariance

# %%
covMat = credit.cov()
print(covMat)
# Out:
#                                       ID     LIMIT_BAL          SEX  \
# ID                          7.500250e+07  2.941664e+07    78.356379
# LIMIT_BAL                   2.941664e+07  1.683446e+10  1571.050630
# SEX                         7.835638e+01  1.571051e+03     0.239247
# EDUCATION                   2.681543e+02 -2.247403e+04     0.005502
# MARRIAGE                   -1.314525e+02 -7.323670e+03    -0.008014
# AGE                         1.491057e+03  1.730767e+05    -0.409726
# PAY_0                      -2.975726e+02 -3.954593e+04    -0.031685
# PAY_2                      -1.162770e+02 -4.603765e+04    -0.041442
# PAY_3                      -1.916922e+02 -4.443225e+04    -0.038694
# PAY_4                      -2.769132e+01 -4.057181e+04    -0.034411
# PAY_5                      -2.178600e+02 -3.667056e+04    -0.030521
# PAY_6                      -2.018774e+02 -3.509308e+04    -0.024754
# BILL_AMT1                   1.236447e+07  2.727020e+09 -1211.694332
# ...

# %%
 type(credit.iloc[0])
# Out:
# pandas.core.series.Series

# %%
credit.iloc[0]
# Out:
# ID                                1
# LIMIT_BAL                     20000
# SEX                               2
# EDUCATION                         2
# MARRIAGE                          1
# AGE                              24
# PAY_0                             2
# PAY_2                             2
# PAY_3                            -1
# PAY_4                            -1
# PAY_5                            -2
# PAY_6                            -2
# BILL_AMT1                      3913
# BILL_AMT2                      3102
# BILL_AMT3                       689
# BILL_AMT4                         0
# BILL_AMT5                         0
# BILL_AMT6                         0
# PAY_AMT1                          0
# PAY_AMT2                        689
# PAY_AMT3                          0
# PAY_AMT4                          0
# PAY_AMT5                          0
# PAY_AMT6                          0
# default payment next month        1
# Name: 0, dtype: int64

# %%
credit.iloc[1:24]
# Out:
#     ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 1    2     120000    2          2         2   26     -1      2      0      0
# 2    3      90000    2          2         2   34      0      0      0      0
# 3    4      50000    2          2         1   37      0      0      0      0
# 4    5      50000    1          2         1   57     -1      0     -1      0
# 5    6      50000    1          1         2   37      0      0      0      0
# 6    7     500000    1          1         2   29      0      0      0      0
# 7    8     100000    2          2         2   23      0     -1     -1      0
# 8    9     140000    2          3         1   28      0      0      2      0
# 9   10      20000    1          3         2   35     -2     -2     -2     -2
# 10  11     200000    2          3         2   34      0      0      2      0
# 11  12     260000    2          1         2   51     -1     -1     -1     -1
# ...

# %%
credit.iloc[2:25]
# Out:
#     ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 2    3      90000    2          2         2   34      0      0      0      0
# 3    4      50000    2          2         1   37      0      0      0      0
# 4    5      50000    1          2         1   57     -1      0     -1      0
# 5    6      50000    1          1         2   37      0      0      0      0
# 6    7     500000    1          1         2   29      0      0      0      0
# 7    8     100000    2          2         2   23      0     -1     -1      0
# 8    9     140000    2          3         1   28      0      0      2      0
# 9   10      20000    1          3         2   35     -2     -2     -2     -2
# 10  11     200000    2          3         2   34      0      0      2      0
# 11  12     260000    2          1         2   51     -1     -1     -1     -1
# 12  13     630000    2          2         2   41     -1      0     -1     -1
# ...

# %%
 type(credit.iloc[1:24])
# Out:
# pandas.core.frame.DataFrame

# %%
credit.iloc[2]
# Out:
# ID                                3
# LIMIT_BAL                     90000
# SEX                               2
# EDUCATION                         2
# MARRIAGE                          2
# AGE                              34
# PAY_0                             0
# PAY_2                             0
# PAY_3                             0
# PAY_4                             0
# PAY_5                             0
# PAY_6                             0
# BILL_AMT1                     29239
# BILL_AMT2                     14027
# BILL_AMT3                     13559
# BILL_AMT4                     14331
# BILL_AMT5                     14948
# BILL_AMT6                     15549
# PAY_AMT1                       1518
# PAY_AMT2                       1500
# PAY_AMT3                       1000
# PAY_AMT4                       1000
# PAY_AMT5                       1000
# PAY_AMT6                       5000
# default payment next month        0
# Name: 2, dtype: int64

# %%
credit.iloc[1,2]
# Out:
# 2

# %%
credit.iloc[1:3, 0:3]
# Out:
#    ID  LIMIT_BAL  SEX
# 1   2     120000    2
# 2   3      90000    2

# %%
covMat = credit.cov().iloc[1]
print(covMat)
# Out:
# ID                            2.941664e+07
# LIMIT_BAL                     1.683446e+10
# SEX                           1.571051e+03
# EDUCATION                    -2.247403e+04
# MARRIAGE                     -7.323670e+03
# AGE                           1.730767e+05
# PAY_0                        -3.954593e+04
# PAY_2                        -4.603765e+04
# PAY_3                        -4.443225e+04
# PAY_4                        -4.057181e+04
# PAY_5                        -3.667056e+04
# PAY_6                        -3.509308e+04
# BILL_AMT1                     2.727020e+09
# BILL_AMT2                     2.570130e+09
# BILL_AMT3                     2.548533e+09
# BILL_AMT4                     2.453926e+09
# BILL_AMT5                     2.331481e+09
# BILL_AMT6                     2.243837e+09
# PAY_AMT1                      4.195711e+08
# PAY_AMT2                      5.333504e+08
# PAY_AMT3                      4.801180e+08
# PAY_AMT4                      4.131202e+08
# ...

# %%
credit.iloc[0:30000, 1:25]
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# 5          50000    1          1         2   37      0      0      0      0
# 6         500000    1          1         2   29      0      0      0      0
# 7         100000    2          2         2   23      0     -1     -1      0
# 8         140000    2          3         1   28      0      0      2      0
# 9          20000    1          3         2   35     -2     -2     -2     -2
# 10        200000    2          3         2   34      0      0      2      0
# ...

# %%
covMat = credit.cov()
print(covMat)
# Out:
#                                       ID     LIMIT_BAL          SEX  \
# ID                          7.500250e+07  2.941664e+07    78.356379
# LIMIT_BAL                   2.941664e+07  1.683446e+10  1571.050630
# SEX                         7.835638e+01  1.571051e+03     0.239247
# EDUCATION                   2.681543e+02 -2.247403e+04     0.005502
# MARRIAGE                   -1.314525e+02 -7.323670e+03    -0.008014
# AGE                         1.491057e+03  1.730767e+05    -0.409726
# PAY_0                      -2.975726e+02 -3.954593e+04    -0.031685
# PAY_2                      -1.162770e+02 -4.603765e+04    -0.041442
# PAY_3                      -1.916922e+02 -4.443225e+04    -0.038694
# PAY_4                      -2.769132e+01 -4.057181e+04    -0.034411
# PAY_5                      -2.178600e+02 -3.667056e+04    -0.030521
# PAY_6                      -2.018774e+02 -3.509308e+04    -0.024754
# BILL_AMT1                   1.236447e+07  2.727020e+09 -1211.694332
# ...

# %%
covMat = credit.cov().iloc[1:25, 1:25]
print(covMat)
# Out:
#                                LIMIT_BAL          SEX     EDUCATION  \
# LIMIT_BAL                   1.683446e+10  1571.050630 -22474.028945
# SEX                         1.571051e+03     0.239247      0.005502
# EDUCATION                  -2.247403e+04     0.005502      0.624651
# MARRIAGE                   -7.323670e+03    -0.008014     -0.059184
# AGE                         1.730767e+05    -0.409726      1.275380
# PAY_0                      -3.954593e+04    -0.031685      0.093584
# PAY_2                      -4.603765e+04    -0.041442      0.115025
# PAY_3                      -4.443225e+04    -0.038694      0.107861
# PAY_4                      -4.057181e+04    -0.034411      0.100528
# PAY_5                      -3.667056e+04    -0.030521      0.087340
# PAY_6                      -3.509308e+04    -0.024754      0.074816
# BILL_AMT1                   2.727020e+09 -1211.694332   1372.377644
# BILL_AMT2                   2.570130e+09 -1085.595467   1054.657595
# ...

# %%
covMat = credit.cov().iloc[1:30000, 1:25]
print(covMat)
# Out:
#                                LIMIT_BAL          SEX     EDUCATION  \
# LIMIT_BAL                   1.683446e+10  1571.050630 -22474.028945
# SEX                         1.571051e+03     0.239247      0.005502
# EDUCATION                  -2.247403e+04     0.005502      0.624651
# MARRIAGE                   -7.323670e+03    -0.008014     -0.059184
# AGE                         1.730767e+05    -0.409726      1.275380
# PAY_0                      -3.954593e+04    -0.031685      0.093584
# PAY_2                      -4.603765e+04    -0.041442      0.115025
# PAY_3                      -4.443225e+04    -0.038694      0.107861
# PAY_4                      -4.057181e+04    -0.034411      0.100528
# PAY_5                      -3.667056e+04    -0.030521      0.087340
# PAY_6                      -3.509308e+04    -0.024754      0.074816
# BILL_AMT1                   2.727020e+09 -1211.694332   1372.377644
# BILL_AMT2                   2.570130e+09 -1085.595467   1054.657595
# ...
