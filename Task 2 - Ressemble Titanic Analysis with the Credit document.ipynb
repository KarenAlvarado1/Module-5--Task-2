# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
credit = pd.read_csv('default of credit card clients.csv', header =1)

# %%
# Check the first 5 rows of the data frame
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...                      0          0          0         0
# 1             ...                   3272       3455       3261         0
# 2             ...                  14331      14948      15549      1518
# 3             ...                  28314      28959      29547      2000
# 4             ...                  20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
# Column names
credit.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
# Information about the data set
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
credit.groupby('AGE')['AGE'].count()
# Out:
# AGE
# 21      67
# 22     560
# 23     931
# 24    1127
# 25    1186
# 26    1256
# 27    1477
# 28    1409
# 29    1605
# 30    1395
# 31    1217
# 32    1158
# 33    1146
# 34    1162
# 35    1113
# 36    1108
# 37    1041
# 38     944
# 39     954
# 40     870
# 41     824
# 42     794
# 43     670
# 44     700
# 45     617
# 46     570
# 47     501
# 48     466
# 49     452
# 50     411
# 51     340
# 52     304
# 53     325
# 54     247
# 55     209
# 56     178
# 57     122
# 58     122
# 59      83
# 60      67
# 61      56
# 62      44
# 63      31
# 64      31
# 65      24
# 66      25
# 67      16
# 68       5
# 69      15
# 70      10
# 71       3
# 72       3
# 73       4
# 74       1
# 75       3
# 79       1
# Name: AGE, dtype: int64

# %%
credit.groupby('SEX')['SEX'].count()
# Out:
# SEX
# 1    11888
# 2    18112
# Name: SEX, dtype: int64

# %%
credit.groupby('MARRIAGE')['MARRIAGE'].count()
# Out:
# MARRIAGE
# 0       54
# 1    13659
# 2    15964
# 3      323
# Name: MARRIAGE, dtype: int64

# %%
credit.groupby('EDUCATION')['EDUCATION'].count()
# Out:
# EDUCATION
# 0       14
# 1    10585
# 2    14030
# 3     4917
# 4      123
# 5      280
# 6       51
# Name: EDUCATION, dtype: int64

# %%
# Using seaborn to plot the Age count
fg = sns.factorplot('AGE', data=credit, kind='count', aspect=1.5)
fg.set_xlabels('AGE')
# Out:
# C:\Users\kalvarado\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# Using seaborn to plot the number of males and females
sns.factorplot('SEX', data=credit, kind='count', aspect=1.5)
# Out:
# C:\Users\kalvarado\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# Number of men and women per marital status
credit.groupby(['SEX', 'MARRIAGE'])['SEX'].count()
# Out:
# SEX  MARRIAGE
# 1    0             14
#      1           5190
#      2           6553
#      3            131
# 2    0             40
#      1           8469
#      2           9411
#      3            192
# Name: SEX, dtype: int64

# %%
# Using saeborn to group by Sex and marital status
g = sns.factorplot('MARRIAGE', data=credit, hue='SEX', kind='count', aspect=1.75)
g.set_xlabels('MARRIAGE')
# Out:
# C:\Users\kalvarado\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# Number of clients who default payment in each marital status grouped by sex.
credit.pivot_table('default payment next month', 'SEX', 'MARRIAGE', aggfunc=np.sum, margins=True)
# Out:
# MARRIAGE  0     1     2   3   All
# SEX
# 1         2  1346  1485  40  2873
# 2         3  1860  1856  44  3763
# All       5  3206  3341  84  6636

# %%
# Factor plot of those with different education levels
sns.factorplot('EDUCATION', data=credit, kind='count')
# Out:
# C:\Users\kalvarado\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
not_default = credit[credit['default payment next month']==0]

# %%
# Total number of clients who didn't default 
len(not_default)
# Out:
# 23364

# %%
# Number of passengers who did not default in each Education level grouped by sex.
not_default.pivot_table('default payment next month', 'SEX', 'EDUCATION', aggfunc=len, margins=True)
# Out:
# EDUCATION   0     1      2     3    4    5   6    All
# SEX
# 1           8  3448   3966  1445   38   89  21   9015
# 2           6  5101   6734  2235   78  173  22  14349
# All        14  8549  10700  3680  116  262  43  23364

# %%
print('Average and median age of clients are %0.f and %0.f years old, respectively'%(credit.AGE.mean(), 
                                                                          credit.AGE.median()))
# Out:
# Average and median age of clients are 35 and 34 years old, respectively

# %%
credit.AGE.describe()
# Out:
# count    30000.000000
# mean        35.485500
# std          9.217904
# min         21.000000
# 25%         28.000000
# 50%         34.000000
# 75%         41.000000
# max         79.000000
# Name: AGE, dtype: float64

# %%
# Drop missing values for the records in which age is missing
AGE = credit['AGE'].dropna()

# %%
# Distribution of age, with an overlay of a density plot
age_dist = sns.distplot(AGE)
age_dist.set_title("Distribution of Passengers' AGES")
# Out:
# Text(0.5, 1.0, "Distribution of Passengers' AGES")

# %%
# Another Histogram of ages
credit['AGE'].hist(bins=50)

# %%
# Create a function to define those who are young adults (between 21 and 25)
def male_female_youngadult(client):
    AGE, SEX = client
    
    if age < 25:
        return 'young.adult'
    else:
        return SEX

# %%
credit['person'] = credit[['AGE','SEX']].apply(male_female_youngadult, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-2ae8e1f4ddcf> in <module>()
# ----> 1 credit['person'] = credit[['AGE','SEX']].apply(male_female_youngadult, axis=1)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
# ...

# %%
#Grouped by Sex
fig = sns.FacetGrid(credit, hue='SEX', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit['AGE'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by Gender')
fig.add_legend()

# %%
#Grouped by Marital Status
fig = sns.FacetGrid(credit, hue='MARRIAGE', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit['AGE'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
#Grouped by Education
fig = sns.FacetGrid(credit, hue='EDUCATION', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit['AGE'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by EDUCATION')
fig.add_legend()

# %%
from collections import Counter

# %%
#Grouped by Balance Limit
fig = sns.FacetGrid(credit, hue='AGE', aspect=4)
fig.map(sns.kdeplot, 'LIMIT_BAL', shade=True)
oldest = credit['LIMIT_BAL'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by BALANCE')
fig.add_legend()
# Out:
# C:\Users\kalvarado\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# C:\Users\kalvarado\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\kalvarado\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py:20: RuntimeWarning: invalid value encountered in minimum
#   return np.minimum(np.std(X, axis=0, ddof=1), IQR)

# %%
credit['count'] = 1

# %%
credit['age_group'] = pd.cut(credit.AGE, [21, 31, 41, 51, 61, 71, 79])

# %%
credit.pivot_table('count', index='age_group', columns='SEX', aggfunc='sum')
# Out:
# SEX           1     2
# age_group
# (21, 31]   4304  7859
# (31, 41]   4233  6087
# (41, 51]   2390  3131
# (51, 61]    819   894
# (61, 71]    114    90
# (71, 79]      7     5

# %%
#Grouped by Age_Group
fig = sns.FacetGrid(credit, hue='age_group', aspect=4)
fig.map(sns.kdeplot, 'LIMIT_BAL', shade=True)
oldest = credit['LIMIT_BAL'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by BALANCE')
fig.add_legend()

# %%
# Now lets factorplot the age_group. First transfer the d list into a data frame. Then rename the column 
sns.factorplot('age_group', data=credit, kind='count', aspect=2, 
              palette='winter_d')
# Out:
# C:\Users\kalvarado\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# For tabulated values, use crosstab pandas method instead of the factorplot in seaborn
AGE_GROUP_DEFAULT = pd.crosstab(index=[credit.default payment next month], columns=[credit.age_group])
# Out:
#   File "<ipython-input-67-aca68f391b50>", line 2
#     AGE_GROUP_DEFAULT = pd.crosstab(index=[credit.default payment next month], columns=[credit.age_group])
#                                                                 ^
# SyntaxError: invalid syntax

# %%
credit.rename(columns={'default payment next month':'DEFAULT'}, inplace=True)

# %%
# For tabulated values, use crosstab pandas method instead of the factorplot in seaborn
AGE_GROUP_DEFAULT = pd.crosstab(index=[credit.DEFAULT], columns=[credit.age_group])

# %%
AGE_GROUP_DEFAULT
# Out:
# age_group  (21, 31]  (31, 41]  (41, 51]  (51, 61]  (61, 71]  (71, 79]
# DEFAULT
# 0              9477      8175      4219      1276       157         7
# 1              2686      2145      1302       437        47         5

# %%
AGE_GROUP_DEFAULT.index=[['No','Yes']]

# %%
AGE_GROUP_DEFAULT
# Out:
# age_group  (21, 31]  (31, 41]  (41, 51]  (51, 61]  (61, 71]  (71, 79]
# DEFAULT
# 0              9477      8175      4219      1276       157         7
# 1              2686      2145      1302       437        47         5

# %%
# Married&University dataframe i.e. the client is married and has a college degree
MarriedUni_df = credit[(credit['MARRIAGE'] == 1) & (credit['EDUCATION']==2)]
# Add MarriedUni column
MarriedUni_df['MarriedUni'] = 'MarriedUni'
# Not alone data frame i.e. the passenger has either a sibling or a parent.
NotMarriedNoUni_df = credit[(credit['MARRIAGE'] != 1) | (credit['EDUCATION']!=2)]
NotMarriedNoUni_df['MarriedUni'] = 'NotMarriedNoUni'
# Out:
# C:\Users\kalvarado\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\kalvarado\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
# Merge the above dataframes
comb = [MarriedUni_df, NotMarriedNoUni_df]
# Merge and sort by index
credit = pd.concat(comb).sort_index()

# %%
[len(MarriedUni_df), len(NotMarriedNoUni_df)]
# Out:
# [6842, 23158]

# %%
# Show the first five records of the MarriedUni data frame
MarriedUni_df.head()
# Out:
#     ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0    1      20000    2          2         1   24      2      2     -1     -1
# 3    4      50000    2          2         1   37      0      0      0      0
# 4    5      50000    1          2         1   57     -1      0     -1      0
# 21  22     120000    2          2         1   39     -1     -1     -1     -1
# 33  34     500000    2          2         1   54     -2     -2     -2     -2
#
#        ...      PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0      ...             0       689         0         0         0         0
# 3      ...          2000      2019      1200      1100      1069      1000
# 4      ...          2000     36681     10000      9000       689       679
# 21     ...           316       316         0       632       316         0
# 33     ...          4152     22827      7521     71439       981     51582
#
#     DEFAULT  count  age_group  MarriedUni
# ...

# %%
fg=sns.factorplot('MarriedUni', data=credit, kind='count', hue='SEX', col='age_group', hue_order=range(1,4),
                 palette='Blues')
fg.set_xlabels('Status')
# Out:
# C:\Users\kalvarado\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# Defaulted vs. Age Grouped by gender
sns.factorplot('SEX','DEFAULT', hue='age_group', data=credit, order=range(1,4))
# Out:
# C:\Users\kalvarado\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# Linear plot of age vs. default
sns.lmplot('AGE', 'DEFAULT', data=credit)

# %%
# Default vs. Age grouped by Sex
sns.lmplot('AGE', 'DEFAULT', data=credit, hue='SEX')

# %%
# Default vs. Age gruped by marital status
sns.lmplot('AGE', 'DEFAULT', hue='MARRIAGE', data=credit, palette='winter', hue_order=range(1,4))

# %%
# Create a generation bin
generations = [10,20,40,60,80]
sns.lmplot('AGE','DEFAULT',hue='MARRIAGE',data=credit,x_bins=generations, hue_order=[1,2,3])
